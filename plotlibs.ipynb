# %%
import os

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")
import pandas as pd

output_dir = os.path.expanduser("~/.local/share/brightlite/brightlite0")
outfile_path = os.path.join(output_dir, "fuel.txt")

# %%
data = pd.read_csv(outfile_path, delim_whitespace=True, index_col=0).transpose()
plt.figure()
data.U235.plot(loglog=True, figsize=(18, 9))
data.U238.plot(loglog=True, figsize=(18, 9))
plt.legend()
