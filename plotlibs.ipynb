# %%
import matplotlib.pyplot as plt
import pandas as pd
import os.path

# %matplotlib inline

# %%
output_dir = os.path.expanduser("~/xslibs/build-lwr1g/")
outfile_path = os.path.join(output_dir, "brightlite.out0-fuel")

# %%
data = pd.read_csv(outfile_path, delim_whitespace=True, index_col=0).transpose()

# %%
plt.figure(figsize=(12, 9))
plt.style.use("ggplot")
data.plot(loglog=True, legend=False)
